# %% [markdown]
# # <p style="font-family:JetBrains Mono; font-weight:bold; letter-spacing: 2px; color:#4F200D; font-size:140%; text-align:center;padding: 0px; border-bottom: 3px solid #4F200D">Importing Packages and Libraries</p>

# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import numpy as np
import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing import OneHotEncoder,LabelEncoder,OrdinalEncoder,StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression,Lasso,Ridge,RidgeClassifier
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split,cross_val_score,GridSearchCV
from sklearn.tree import DecisionTreeClassifier
import pickle as pk

# %% [markdown]
# # <p style="font-family:JetBrains Mono; font-weight:bold; letter-spacing: 2px; color:#4F200D; font-size:140%; text-align:center;padding: 0px; border-bottom: 3px solid #4F200D">Data Loading</p>

# %%
data=pd.read_csv('/kaggle/input/drug-classification/drug200.csv')

# %% [markdown]
# # <p style="font-family:JetBrains Mono; font-weight:bold; letter-spacing: 2px; color:#4F200D; font-size:140%; text-align:center;padding: 0px; border-bottom: 3px solid #4F200D">Data Cleaning</p>

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Age          200 non-null    int64
#  1   Sex          200 non-null    object
#  2   BP           200 non-null    object
#  3   Cholesterol  200 non-null    object
#  4   Na_to_K      200 non-null    float64
#  5   Drug         200 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 9.5+ KB

# %% [markdown]
# # <p style="font-family:JetBrains Mono; font-weight:bold; letter-spacing: 2px; color:#4F200D; font-size:140%; text-align:center;padding: 0px; border-bottom: 3px solid #4F200D">Machine Learning</p>

# %% [markdown]
# <div style="background-color: #000; padding: 10px; text-align: center; border-radius: 5px; box-shadow: 0 0 10px rgba(255, 255, 255, 0.7);">
#     <p style="font-family: 'JetBrains Mono', monospace; font-weight: bold; letter-spacing: 2px; color: #3498db; font-size: 140%; text-shadow: 0 0 10px rgba(255, 255, 255, 0.7);">Constructing Encoders For Data Model</p>
# </div>

# %%
one=OneHotEncoder(handle_unknown='ignore',sparse=False)

# %%
le=LabelEncoder()

# %%
target=le.fit_transform(data['Drug'])

# %%
std=('standard',StandardScaler(),['Age','Na_to_K'])

# %%
data.drop(['Drug'],axis=1,inplace=True)

# %%
encode=('one',one,data.columns)

# %% [markdown]
# <div style="background-color: #000; padding: 10px; text-align: center; border-radius: 5px; box-shadow: 0 0 10px rgba(255, 255, 255, 0.7);">
#     <p style="font-family: 'JetBrains Mono', monospace; font-weight: bold; letter-spacing: 2px; color: #3498db; font-size: 140%; text-shadow: 0 0 10px rgba(255, 255, 255, 0.7);">Splitting Data</p>
# </div>

# %%
xtra,xtest,ytra,ytest=train_test_split(data,target,test_size=0.2,random_state=456)

# %%
col=ColumnTransformer(transformers=[std,encode])

# %% [markdown]
# <div style="background-color: #000; padding: 10px; text-align: center; border-radius: 5px; box-shadow: 0 0 10px rgba(255, 255, 255, 0.7);">
#     <p style="font-family: 'JetBrains Mono', monospace; font-weight: bold; letter-spacing: 2px; color: #3498db; font-size: 140%; text-shadow: 0 0 10px rgba(255, 255, 255, 0.7);">Maachine Learning Models</p>
# </div>

# %%
model1=RandomForestClassifier()
model2=SVC()
model3=LogisticRegression()
model4=KNeighborsClassifier()
model5=DecisionTreeClassifier()
la=Lasso()
ri=RidgeClassifier()

# %%
model6=GridSearchCV(ri,param_grid = {'alpha': np.logspace(-4, 4, 9)},cv=5,verbose=2,scoring='accuracy')

# %%
model7=GridSearchCV(ri,param_grid = {'alpha': np.logspace(-4, 4, 9)},cv=5,verbose=2,scoring='accuracy')

# %% [markdown]
# <div style="background-color: #000; padding: 10px; text-align: center; border-radius: 5px; box-shadow: 0 0 10px rgba(255, 255, 255, 0.7);">
#     <p style="font-family: 'JetBrains Mono', monospace; font-weight: bold; letter-spacing: 2px; color: #3498db; font-size: 140%; text-shadow: 0 0 10px rgba(255, 255, 255, 0.7);">Constructing Pipelines</p>
# </div>

# %%
pipe1=Pipeline(steps=[('col',col),('model1',model1)])
pipe2=Pipeline(steps=[('col',col),('model2',model2)])
pipe3=Pipeline(steps=[('col',col),('model3',model3)])
pipe4=Pipeline(steps=[('col',col),('model4',model4)])

pipe5=Pipeline(steps=[('col',col),('model5',model5)])
pipe6=Pipeline(steps=[('col',col),('model6',model6)])
pipe7=Pipeline(steps=[('col',col),('model7',model7)])

# %% [markdown]
# # <p style="font-family:JetBrains Mono; font-weight:bold; letter-spacing: 2px; color:#4F200D; font-size:140%; text-align:center;padding: 0px; border-bottom: 3px solid #4F200D">Results</p>

# %%
c1,c2,c3,c4,c5,c6,c7=cross_val_score(pipe1,data,target),cross_val_score(pipe2,xtest,ytest),cross_val_score(pipe3,xtest,ytest),cross_val_score(pipe4,xtest,ytest),cross_val_score(pipe5,xtest,ytest),cross_val_score(pipe6,xtest,ytest),cross_val_score(pipe7,xtest,ytest)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] END .......................................alpha=0.0001; total time=   0.0s
# [CV] END .......................................alpha=0.0001; total time=   0.0s
# [CV] END .......................................alpha=0.0001; total time=   0.0s
# [CV] END .......................................alpha=0.0001; total time=   0.0s
# [CV] END .......................................alpha=0.0001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=1.0; total time=   0.0s
# [CV] END ..........................................alpha=1.0; total time=   0.0s
# [CV] END ..........................................alpha=1.0; total time=   0.0s
# [CV] END ..........................................alpha=1.0; total time=   0.0s
# [CV] END ..........................................alpha=1.0; total time=   0.0s
# [CV] END .........................................alpha=10.0; total time=   0.0s
# [CV] END .........................................alpha=10.0; total time=   0.0s
# [CV] END .........................................alpha=10.0; total time=   0.0s
# [CV] END .........................................alpha=10.0; total time=   0.0s
# [CV] END .........................................alpha=10.0; total time=   0.0s
# [CV] END ........................................alpha=100.0; total time=   0.0s
# [CV] END ........................................alpha=100.0; total time=   0.0s
# [CV] END ........................................alpha=100.0; total time=   0.0s
# [CV] END ........................................alpha=100.0; total time=   0.0s
# [CV] END ........................................alpha=100.0; total time=   0.0s
# [CV] END .......................................alpha=1000.0; total time=   0.0s
# [CV] END .......................................alpha=1000.0; total time=   0.0s
# [CV] END .......................................alpha=1000.0; total time=   0.0s
# [CV] END .......................................alpha=1000.0; total time=   0.0s
# [CV] END .......................................alpha=1000.0; total time=   0.0s
# [CV] END ......................................alpha=10000.0; total time=   0.0s
# [CV] END ......................................alpha=10000.0; total time=   0.0s
# [CV] END ......................................alpha=10000.0; total time=   0.0s
# [CV] END ......................................alpha=10000.0; total time=   0.0s
# [CV] END ......................................alpha=10000.0; total time=   0.0s
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] END .......................................alpha=0.0001; total time=   0.0s
# [CV] END .......................................alpha=0.0001; total time=   0.0s
# [CV] END .......................................alpha=0.0001; total time=   0.0s
# [CV] END .......................................alpha=0.0001; total time=   0.0s
# [CV] END .......................................alpha=0.0001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=1.0; total time=   0.0s
# [CV] END ..........................................alpha=1.0; total time=   0.0s
# [CV] END ..........................................alpha=1.0; total time=   0.0s
# [CV] END ..........................................alpha=1.0; total time=   0.0s
# [CV] END ..........................................alpha=1.0; total time=   0.0s
# [CV] END .........................................alpha=10.0; total time=   0.0s
# [CV] END .........................................alpha=10.0; total time=   0.0s
# [CV] END .........................................alpha=10.0; total time=   0.0s
# [CV] END .........................................alpha=10.0; total time=   0.0s
# [CV] END .........................................alpha=10.0; total time=   0.0s
# [CV] END ........................................alpha=100.0; total time=   0.0s
# [CV] END ........................................alpha=100.0; total time=   0.0s
# [CV] END ........................................alpha=100.0; total time=   0.0s
# [CV] END ........................................alpha=100.0; total time=   0.0s
# [CV] END ........................................alpha=100.0; total time=   0.0s
# [CV] END .......................................alpha=1000.0; total time=   0.0s
# [CV] END .......................................alpha=1000.0; total time=   0.0s
# [CV] END .......................................alpha=1000.0; total time=   0.0s
# [CV] END .......................................alpha=1000.0; total time=   0.0s
# [CV] END .......................................alpha=1000.0; total time=   0.0s
# [CV] END ......................................alpha=10000.0; total time=   0.0s
# [CV] END ......................................alpha=10000.0; total time=   0.0s
# [CV] END ......................................alpha=10000.0; total time=   0.0s
# [CV] END ......................................alpha=10000.0; total time=   0.0s
# [CV] END ......................................alpha=10000.0; total time=   0.0s
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] END .......................................alpha=0.0001; total time=   0.0s
# [CV] END .......................................alpha=0.0001; total time=   0.0s
# [CV] END .......................................alpha=0.0001; total time=   0.0s
# [CV] END .......................................alpha=0.0001; total time=   0.0s
# [CV] END .......................................alpha=0.0001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=1.0; total time=   0.0s
# [CV] END ..........................................alpha=1.0; total time=   0.0s
# [CV] END ..........................................alpha=1.0; total time=   0.0s
# [CV] END ..........................................alpha=1.0; total time=   0.0s
# [CV] END ..........................................alpha=1.0; total time=   0.0s
# [CV] END .........................................alpha=10.0; total time=   0.0s
# [CV] END .........................................alpha=10.0; total time=   0.0s
# [CV] END .........................................alpha=10.0; total time=   0.0s
# [CV] END .........................................alpha=10.0; total time=   0.0s
# [CV] END .........................................alpha=10.0; total time=   0.0s
# [CV] END ........................................alpha=100.0; total time=   0.0s
# [CV] END ........................................alpha=100.0; total time=   0.0s
# [CV] END ........................................alpha=100.0; total time=   0.0s
# [CV] END ........................................alpha=100.0; total time=   0.0s
# [CV] END ........................................alpha=100.0; total time=   0.0s
# [CV] END .......................................alpha=1000.0; total time=   0.0s
# [CV] END .......................................alpha=1000.0; total time=   0.0s
# [CV] END .......................................alpha=1000.0; total time=   0.0s
# [CV] END .......................................alpha=1000.0; total time=   0.0s
# [CV] END .......................................alpha=1000.0; total time=   0.0s
# [CV] END ......................................alpha=10000.0; total time=   0.0s
# [CV] END ......................................alpha=10000.0; total time=   0.0s
# [CV] END ......................................alpha=10000.0; total time=   0.0s
# [CV] END ......................................alpha=10000.0; total time=   0.0s
# [CV] END ......................................alpha=10000.0; total time=   0.0s
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] END .......................................alpha=0.0001; total time=   0.0s
# [CV] END .......................................alpha=0.0001; total time=   0.0s
# [CV] END .......................................alpha=0.0001; total time=   0.0s
# [CV] END .......................................alpha=0.0001; total time=   0.0s
# [CV] END .......................................alpha=0.0001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=1.0; total time=   0.0s
# [CV] END ..........................................alpha=1.0; total time=   0.0s
# [CV] END ..........................................alpha=1.0; total time=   0.0s
# [CV] END ..........................................alpha=1.0; total time=   0.0s
# [CV] END ..........................................alpha=1.0; total time=   0.0s
# [CV] END .........................................alpha=10.0; total time=   0.0s
# [CV] END .........................................alpha=10.0; total time=   0.0s
# [CV] END .........................................alpha=10.0; total time=   0.0s
# [CV] END .........................................alpha=10.0; total time=   0.0s
# [CV] END .........................................alpha=10.0; total time=   0.0s
# [CV] END ........................................alpha=100.0; total time=   0.0s
# [CV] END ........................................alpha=100.0; total time=   0.0s
# [CV] END ........................................alpha=100.0; total time=   0.0s
# [CV] END ........................................alpha=100.0; total time=   0.0s
# [CV] END ........................................alpha=100.0; total time=   0.0s
# [CV] END .......................................alpha=1000.0; total time=   0.0s
# [CV] END .......................................alpha=1000.0; total time=   0.0s
# [CV] END .......................................alpha=1000.0; total time=   0.0s
# [CV] END .......................................alpha=1000.0; total time=   0.0s
# [CV] END .......................................alpha=1000.0; total time=   0.0s
# [CV] END ......................................alpha=10000.0; total time=   0.0s
# [CV] END ......................................alpha=10000.0; total time=   0.0s
# [CV] END ......................................alpha=10000.0; total time=   0.0s
# [CV] END ......................................alpha=10000.0; total time=   0.0s
# [CV] END ......................................alpha=10000.0; total time=   0.0s
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] END .......................................alpha=0.0001; total time=   0.0s
# [CV] END .......................................alpha=0.0001; total time=   0.0s
# [CV] END .......................................alpha=0.0001; total time=   0.0s
# [CV] END .......................................alpha=0.0001; total time=   0.0s
# [CV] END .......................................alpha=0.0001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=1.0; total time=   0.0s
# [CV] END ..........................................alpha=1.0; total time=   0.0s
# [CV] END ..........................................alpha=1.0; total time=   0.0s
# [CV] END ..........................................alpha=1.0; total time=   0.0s
# [CV] END ..........................................alpha=1.0; total time=   0.0s
# [CV] END .........................................alpha=10.0; total time=   0.0s
# [CV] END .........................................alpha=10.0; total time=   0.0s
# [CV] END .........................................alpha=10.0; total time=   0.0s
# [CV] END .........................................alpha=10.0; total time=   0.0s
# [CV] END .........................................alpha=10.0; total time=   0.0s
# [CV] END ........................................alpha=100.0; total time=   0.0s
# [CV] END ........................................alpha=100.0; total time=   0.0s
# [CV] END ........................................alpha=100.0; total time=   0.0s
# [CV] END ........................................alpha=100.0; total time=   0.0s
# [CV] END ........................................alpha=100.0; total time=   0.0s
# [CV] END .......................................alpha=1000.0; total time=   0.0s
# [CV] END .......................................alpha=1000.0; total time=   0.0s
# [CV] END .......................................alpha=1000.0; total time=   0.0s
# [CV] END .......................................alpha=1000.0; total time=   0.0s
# [CV] END .......................................alpha=1000.0; total time=   0.0s
# [CV] END ......................................alpha=10000.0; total time=   0.0s
# [CV] END ......................................alpha=10000.0; total time=   0.0s
# [CV] END ......................................alpha=10000.0; total time=   0.0s
# [CV] END ......................................alpha=10000.0; total time=   0.0s
# [CV] END ......................................alpha=10000.0; total time=   0.0s
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] END .......................................alpha=0.0001; total time=   0.0s
# [CV] END .......................................alpha=0.0001; total time=   0.0s
# [CV] END .......................................alpha=0.0001; total time=   0.0s
# [CV] END .......................................alpha=0.0001; total time=   0.0s
# [CV] END .......................................alpha=0.0001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=1.0; total time=   0.0s
# [CV] END ..........................................alpha=1.0; total time=   0.0s
# [CV] END ..........................................alpha=1.0; total time=   0.0s
# [CV] END ..........................................alpha=1.0; total time=   0.0s
# [CV] END ..........................................alpha=1.0; total time=   0.0s
# [CV] END .........................................alpha=10.0; total time=   0.0s
# [CV] END .........................................alpha=10.0; total time=   0.0s
# [CV] END .........................................alpha=10.0; total time=   0.0s
# [CV] END .........................................alpha=10.0; total time=   0.0s
# [CV] END .........................................alpha=10.0; total time=   0.0s
# [CV] END ........................................alpha=100.0; total time=   0.0s
# [CV] END ........................................alpha=100.0; total time=   0.0s
# [CV] END ........................................alpha=100.0; total time=   0.0s
# [CV] END ........................................alpha=100.0; total time=   0.0s
# [CV] END ........................................alpha=100.0; total time=   0.0s
# [CV] END .......................................alpha=1000.0; total time=   0.0s
# [CV] END .......................................alpha=1000.0; total time=   0.0s
# [CV] END .......................................alpha=1000.0; total time=   0.0s
# [CV] END .......................................alpha=1000.0; total time=   0.0s
# [CV] END .......................................alpha=1000.0; total time=   0.0s
# [CV] END ......................................alpha=10000.0; total time=   0.0s
# [CV] END ......................................alpha=10000.0; total time=   0.0s
# [CV] END ......................................alpha=10000.0; total time=   0.0s
# [CV] END ......................................alpha=10000.0; total time=   0.0s
# [CV] END ......................................alpha=10000.0; total time=   0.0s
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] END .......................................alpha=0.0001; total time=   0.0s
# [CV] END .......................................alpha=0.0001; total time=   0.0s
# [CV] END .......................................alpha=0.0001; total time=   0.0s
# [CV] END .......................................alpha=0.0001; total time=   0.0s
# [CV] END .......................................alpha=0.0001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=1.0; total time=   0.0s
# [CV] END ..........................................alpha=1.0; total time=   0.0s
# [CV] END ..........................................alpha=1.0; total time=   0.0s
# [CV] END ..........................................alpha=1.0; total time=   0.0s
# [CV] END ..........................................alpha=1.0; total time=   0.0s
# [CV] END .........................................alpha=10.0; total time=   0.0s
# [CV] END .........................................alpha=10.0; total time=   0.0s
# [CV] END .........................................alpha=10.0; total time=   0.0s
# [CV] END .........................................alpha=10.0; total time=   0.0s
# [CV] END .........................................alpha=10.0; total time=   0.0s
# [CV] END ........................................alpha=100.0; total time=   0.0s
# [CV] END ........................................alpha=100.0; total time=   0.0s
# [CV] END ........................................alpha=100.0; total time=   0.0s
# [CV] END ........................................alpha=100.0; total time=   0.0s
# [CV] END ........................................alpha=100.0; total time=   0.0s
# [CV] END .......................................alpha=1000.0; total time=   0.0s
# [CV] END .......................................alpha=1000.0; total time=   0.0s
# [CV] END .......................................alpha=1000.0; total time=   0.0s
# [CV] END .......................................alpha=1000.0; total time=   0.0s
# [CV] END .......................................alpha=1000.0; total time=   0.0s
# [CV] END ......................................alpha=10000.0; total time=   0.0s
# [CV] END ......................................alpha=10000.0; total time=   0.0s
# [CV] END ......................................alpha=10000.0; total time=   0.0s
# [CV] END ......................................alpha=10000.0; total time=   0.0s
# [CV] END ......................................alpha=10000.0; total time=   0.0s
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] END .......................................alpha=0.0001; total time=   0.0s
# [CV] END .......................................alpha=0.0001; total time=   0.0s
# [CV] END .......................................alpha=0.0001; total time=   0.0s
# [CV] END .......................................alpha=0.0001; total time=   0.0s
# [CV] END .......................................alpha=0.0001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=1.0; total time=   0.0s
# [CV] END ..........................................alpha=1.0; total time=   0.0s
# [CV] END ..........................................alpha=1.0; total time=   0.0s
# [CV] END ..........................................alpha=1.0; total time=   0.0s
# [CV] END ..........................................alpha=1.0; total time=   0.0s
# [CV] END .........................................alpha=10.0; total time=   0.0s
# [CV] END .........................................alpha=10.0; total time=   0.0s
# [CV] END .........................................alpha=10.0; total time=   0.0s
# [CV] END .........................................alpha=10.0; total time=   0.0s
# [CV] END .........................................alpha=10.0; total time=   0.0s
# [CV] END ........................................alpha=100.0; total time=   0.0s
# [CV] END ........................................alpha=100.0; total time=   0.0s
# [CV] END ........................................alpha=100.0; total time=   0.0s
# [CV] END ........................................alpha=100.0; total time=   0.0s
# [CV] END ........................................alpha=100.0; total time=   0.0s
# [CV] END .......................................alpha=1000.0; total time=   0.0s
# [CV] END .......................................alpha=1000.0; total time=   0.0s
# [CV] END .......................................alpha=1000.0; total time=   0.0s
# [CV] END .......................................alpha=1000.0; total time=   0.0s
# [CV] END .......................................alpha=1000.0; total time=   0.0s
# [CV] END ......................................alpha=10000.0; total time=   0.0s
# [CV] END ......................................alpha=10000.0; total time=   0.0s
# [CV] END ......................................alpha=10000.0; total time=   0.0s
# [CV] END ......................................alpha=10000.0; total time=   0.0s
# [CV] END ......................................alpha=10000.0; total time=   0.0s
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] END .......................................alpha=0.0001; total time=   0.0s
# [CV] END .......................................alpha=0.0001; total time=   0.0s
# [CV] END .......................................alpha=0.0001; total time=   0.0s
# [CV] END .......................................alpha=0.0001; total time=   0.0s
# [CV] END .......................................alpha=0.0001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=1.0; total time=   0.0s
# [CV] END ..........................................alpha=1.0; total time=   0.0s
# [CV] END ..........................................alpha=1.0; total time=   0.0s
# [CV] END ..........................................alpha=1.0; total time=   0.0s
# [CV] END ..........................................alpha=1.0; total time=   0.0s
# [CV] END .........................................alpha=10.0; total time=   0.0s
# [CV] END .........................................alpha=10.0; total time=   0.0s
# [CV] END .........................................alpha=10.0; total time=   0.0s
# [CV] END .........................................alpha=10.0; total time=   0.0s
# [CV] END .........................................alpha=10.0; total time=   0.0s
# [CV] END ........................................alpha=100.0; total time=   0.0s
# [CV] END ........................................alpha=100.0; total time=   0.0s
# [CV] END ........................................alpha=100.0; total time=   0.0s
# [CV] END ........................................alpha=100.0; total time=   0.0s
# [CV] END ........................................alpha=100.0; total time=   0.0s
# [CV] END .......................................alpha=1000.0; total time=   0.0s
# [CV] END .......................................alpha=1000.0; total time=   0.0s
# [CV] END .......................................alpha=1000.0; total time=   0.0s
# [CV] END .......................................alpha=1000.0; total time=   0.0s
# [CV] END .......................................alpha=1000.0; total time=   0.0s
# [CV] END ......................................alpha=10000.0; total time=   0.0s
# [CV] END ......................................alpha=10000.0; total time=   0.0s
# [CV] END ......................................alpha=10000.0; total time=   0.0s
# [CV] END ......................................alpha=10000.0; total time=   0.0s
# [CV] END ......................................alpha=10000.0; total time=   0.0s
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] END .......................................alpha=0.0001; total time=   0.0s
# [CV] END .......................................alpha=0.0001; total time=   0.0s
# [CV] END .......................................alpha=0.0001; total time=   0.0s
# [CV] END .......................................alpha=0.0001; total time=   0.0s
# [CV] END .......................................alpha=0.0001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END .........................................alpha=0.01; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=1.0; total time=   0.0s
# [CV] END ..........................................alpha=1.0; total time=   0.0s
# [CV] END ..........................................alpha=1.0; total time=   0.0s
# [CV] END ..........................................alpha=1.0; total time=   0.0s
# [CV] END ..........................................alpha=1.0; total time=   0.0s
# [CV] END .........................................alpha=10.0; total time=   0.0s
# [CV] END .........................................alpha=10.0; total time=   0.0s
# [CV] END .........................................alpha=10.0; total time=   0.0s
# [CV] END .........................................alpha=10.0; total time=   0.0s
# [CV] END .........................................alpha=10.0; total time=   0.0s
# [CV] END ........................................alpha=100.0; total time=   0.0s
# [CV] END ........................................alpha=100.0; total time=   0.0s
# [CV] END ........................................alpha=100.0; total time=   0.0s
# [CV] END ........................................alpha=100.0; total time=   0.0s
# [CV] END ........................................alpha=100.0; total time=   0.0s
# [CV] END .......................................alpha=1000.0; total time=   0.0s
# [CV] END .......................................alpha=1000.0; total time=   0.0s
# [CV] END .......................................alpha=1000.0; total time=   0.0s
# [CV] END .......................................alpha=1000.0; total time=   0.0s
# [CV] END .......................................alpha=1000.0; total time=   0.0s
# [CV] END ......................................alpha=10000.0; total time=   0.0s
# [CV] END ......................................alpha=10000.0; total time=   0.0s
# [CV] END ......................................alpha=10000.0; total time=   0.0s
# [CV] END ......................................alpha=10000.0; total time=   0.0s
# [CV] END ......................................alpha=10000.0; total time=   0.0s

# %%
print('Cross_Val_Scores:\nRandomForestClassifier:{:.2f}\nSVC:{:.2f}\nLogisticRegression:{:.2f}\nKNeighborsClassifier:{:.2f}\nDecisionTreeClassifier:{:.2f}\nRigdeModel:{:.2f}\nLassoModel:{:.2f}'.format(c1.mean(),c2.mean(),c3.mean(),c4.mean(),c5.mean(),c6.mean(),c7.mean()))
# Out:
# Cross_Val_Scores:
# RandomForestClassifier:0.97
# SVC:0.65
# LogisticRegression:0.78
# KNeighborsClassifier:0.72
# DecisionTreeClassifier:0.93
# RigdeModel:0.68
# LassoModel:0.68

# %%
models=['RandomForestClassifier','LogisticRegression','DecisionTreeClassifier','RidgeModel','LassoModel','SVC','KNeighborsClassifier']
modelcrossval=[c1,c3,c5,c6,c7,c2,c4]

# %% [markdown]
# # <p style="font-family:JetBrains Mono; font-weight:bold; letter-spacing: 2px; color:#4F200D; font-size:140%; text-align:center;padding: 0px; border-bottom: 3px solid #4F200D">HyperParameter Tuning</p>

# %% [markdown]
# <div style="background-color: #000; padding: 10px; text-align: center; border-radius: 5px; box-shadow: 0 0 10px rgba(255, 255, 255, 0.7);">
#     <p style="font-family: 'JetBrains Mono', monospace; font-weight: bold; letter-spacing: 2px; color: #3498db; font-size: 140%; text-shadow: 0 0 10px rgba(255, 255, 255, 0.7);">Decision Tree Model Tuning</p>
# </div>

# %%
newmodel=GridSearchCV(pipe5,param_grid = {
    'model5__max_depth': [None, 10, 20, 30],
    'model5__min_samples_split': [2, 5, 10],
    'model5__min_samples_leaf': [1, 2, 4],
    'model5__max_features': ['auto', 'sqrt', 'log2'],
},cv=5,verbose=2,scoring='f1')

# %%
newmodel.fit(xtra,ytra)
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# [CV] END model5__max_depth=None, model5__max_features=auto, model5__min_samples_leaf=1, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=auto, model5__min_samples_leaf=1, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=auto, model5__min_samples_leaf=1, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=auto, model5__min_samples_leaf=1, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=auto, model5__min_samples_leaf=1, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=auto, model5__min_samples_leaf=1, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=auto, model5__min_samples_leaf=1, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=auto, model5__min_samples_leaf=1, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=auto, model5__min_samples_leaf=1, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=auto, model5__min_samples_leaf=1, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=auto, model5__min_samples_leaf=1, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=auto, model5__min_samples_leaf=1, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=auto, model5__min_samples_leaf=1, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=auto, model5__min_samples_leaf=1, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=auto, model5__min_samples_leaf=1, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=auto, model5__min_samples_leaf=2, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=auto, model5__min_samples_leaf=2, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=auto, model5__min_samples_leaf=2, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=auto, model5__min_samples_leaf=2, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=auto, model5__min_samples_leaf=2, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=auto, model5__min_samples_leaf=2, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=auto, model5__min_samples_leaf=2, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=auto, model5__min_samples_leaf=2, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=auto, model5__min_samples_leaf=2, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=auto, model5__min_samples_leaf=2, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=auto, model5__min_samples_leaf=2, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=auto, model5__min_samples_leaf=2, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=auto, model5__min_samples_leaf=2, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=auto, model5__min_samples_leaf=2, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=auto, model5__min_samples_leaf=2, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=auto, model5__min_samples_leaf=4, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=auto, model5__min_samples_leaf=4, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=auto, model5__min_samples_leaf=4, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=auto, model5__min_samples_leaf=4, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=auto, model5__min_samples_leaf=4, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=auto, model5__min_samples_leaf=4, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=auto, model5__min_samples_leaf=4, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=auto, model5__min_samples_leaf=4, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=auto, model5__min_samples_leaf=4, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=auto, model5__min_samples_leaf=4, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=auto, model5__min_samples_leaf=4, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=auto, model5__min_samples_leaf=4, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=auto, model5__min_samples_leaf=4, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=auto, model5__min_samples_leaf=4, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=auto, model5__min_samples_leaf=4, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=sqrt, model5__min_samples_leaf=1, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=sqrt, model5__min_samples_leaf=1, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=sqrt, model5__min_samples_leaf=1, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=sqrt, model5__min_samples_leaf=1, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=sqrt, model5__min_samples_leaf=1, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=sqrt, model5__min_samples_leaf=1, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=sqrt, model5__min_samples_leaf=1, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=sqrt, model5__min_samples_leaf=1, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=sqrt, model5__min_samples_leaf=1, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=sqrt, model5__min_samples_leaf=1, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=sqrt, model5__min_samples_leaf=1, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=sqrt, model5__min_samples_leaf=1, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=sqrt, model5__min_samples_leaf=1, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=sqrt, model5__min_samples_leaf=1, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=sqrt, model5__min_samples_leaf=1, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=sqrt, model5__min_samples_leaf=2, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=sqrt, model5__min_samples_leaf=2, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=sqrt, model5__min_samples_leaf=2, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=sqrt, model5__min_samples_leaf=2, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=sqrt, model5__min_samples_leaf=2, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=sqrt, model5__min_samples_leaf=2, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=sqrt, model5__min_samples_leaf=2, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=sqrt, model5__min_samples_leaf=2, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=sqrt, model5__min_samples_leaf=2, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=sqrt, model5__min_samples_leaf=2, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=sqrt, model5__min_samples_leaf=2, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=sqrt, model5__min_samples_leaf=2, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=sqrt, model5__min_samples_leaf=2, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=sqrt, model5__min_samples_leaf=2, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=sqrt, model5__min_samples_leaf=2, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=sqrt, model5__min_samples_leaf=4, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=sqrt, model5__min_samples_leaf=4, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=sqrt, model5__min_samples_leaf=4, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=sqrt, model5__min_samples_leaf=4, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=sqrt, model5__min_samples_leaf=4, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=sqrt, model5__min_samples_leaf=4, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=sqrt, model5__min_samples_leaf=4, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=sqrt, model5__min_samples_leaf=4, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=sqrt, model5__min_samples_leaf=4, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=sqrt, model5__min_samples_leaf=4, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=sqrt, model5__min_samples_leaf=4, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=sqrt, model5__min_samples_leaf=4, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=sqrt, model5__min_samples_leaf=4, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=sqrt, model5__min_samples_leaf=4, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=sqrt, model5__min_samples_leaf=4, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=log2, model5__min_samples_leaf=1, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=log2, model5__min_samples_leaf=1, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=log2, model5__min_samples_leaf=1, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=log2, model5__min_samples_leaf=1, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=log2, model5__min_samples_leaf=1, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=log2, model5__min_samples_leaf=1, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=log2, model5__min_samples_leaf=1, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=log2, model5__min_samples_leaf=1, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=log2, model5__min_samples_leaf=1, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=log2, model5__min_samples_leaf=1, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=log2, model5__min_samples_leaf=1, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=log2, model5__min_samples_leaf=1, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=log2, model5__min_samples_leaf=1, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=log2, model5__min_samples_leaf=1, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=log2, model5__min_samples_leaf=1, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=log2, model5__min_samples_leaf=2, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=log2, model5__min_samples_leaf=2, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=log2, model5__min_samples_leaf=2, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=log2, model5__min_samples_leaf=2, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=log2, model5__min_samples_leaf=2, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=log2, model5__min_samples_leaf=2, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=log2, model5__min_samples_leaf=2, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=log2, model5__min_samples_leaf=2, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=log2, model5__min_samples_leaf=2, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=log2, model5__min_samples_leaf=2, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=log2, model5__min_samples_leaf=2, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=log2, model5__min_samples_leaf=2, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=log2, model5__min_samples_leaf=2, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=log2, model5__min_samples_leaf=2, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=log2, model5__min_samples_leaf=2, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=log2, model5__min_samples_leaf=4, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=log2, model5__min_samples_leaf=4, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=log2, model5__min_samples_leaf=4, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=log2, model5__min_samples_leaf=4, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=log2, model5__min_samples_leaf=4, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=log2, model5__min_samples_leaf=4, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=log2, model5__min_samples_leaf=4, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=log2, model5__min_samples_leaf=4, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=log2, model5__min_samples_leaf=4, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=log2, model5__min_samples_leaf=4, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=log2, model5__min_samples_leaf=4, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=log2, model5__min_samples_leaf=4, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=log2, model5__min_samples_leaf=4, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=log2, model5__min_samples_leaf=4, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=None, model5__max_features=log2, model5__min_samples_leaf=4, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=auto, model5__min_samples_leaf=1, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=auto, model5__min_samples_leaf=1, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=auto, model5__min_samples_leaf=1, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=auto, model5__min_samples_leaf=1, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=auto, model5__min_samples_leaf=1, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=auto, model5__min_samples_leaf=1, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=auto, model5__min_samples_leaf=1, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=auto, model5__min_samples_leaf=1, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=auto, model5__min_samples_leaf=1, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=auto, model5__min_samples_leaf=1, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=auto, model5__min_samples_leaf=1, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=auto, model5__min_samples_leaf=1, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=auto, model5__min_samples_leaf=1, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=auto, model5__min_samples_leaf=1, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=auto, model5__min_samples_leaf=1, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=auto, model5__min_samples_leaf=2, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=auto, model5__min_samples_leaf=2, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=auto, model5__min_samples_leaf=2, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=auto, model5__min_samples_leaf=2, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=auto, model5__min_samples_leaf=2, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=auto, model5__min_samples_leaf=2, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=auto, model5__min_samples_leaf=2, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=auto, model5__min_samples_leaf=2, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=auto, model5__min_samples_leaf=2, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=auto, model5__min_samples_leaf=2, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=auto, model5__min_samples_leaf=2, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=auto, model5__min_samples_leaf=2, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=auto, model5__min_samples_leaf=2, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=auto, model5__min_samples_leaf=2, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=auto, model5__min_samples_leaf=2, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=auto, model5__min_samples_leaf=4, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=auto, model5__min_samples_leaf=4, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=auto, model5__min_samples_leaf=4, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=auto, model5__min_samples_leaf=4, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=auto, model5__min_samples_leaf=4, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=auto, model5__min_samples_leaf=4, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=auto, model5__min_samples_leaf=4, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=auto, model5__min_samples_leaf=4, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=auto, model5__min_samples_leaf=4, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=auto, model5__min_samples_leaf=4, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=auto, model5__min_samples_leaf=4, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=auto, model5__min_samples_leaf=4, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=auto, model5__min_samples_leaf=4, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=auto, model5__min_samples_leaf=4, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=auto, model5__min_samples_leaf=4, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=sqrt, model5__min_samples_leaf=1, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=sqrt, model5__min_samples_leaf=1, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=sqrt, model5__min_samples_leaf=1, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=sqrt, model5__min_samples_leaf=1, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=sqrt, model5__min_samples_leaf=1, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=sqrt, model5__min_samples_leaf=1, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=sqrt, model5__min_samples_leaf=1, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=sqrt, model5__min_samples_leaf=1, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=sqrt, model5__min_samples_leaf=1, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=sqrt, model5__min_samples_leaf=1, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=sqrt, model5__min_samples_leaf=1, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=sqrt, model5__min_samples_leaf=1, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=sqrt, model5__min_samples_leaf=1, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=sqrt, model5__min_samples_leaf=1, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=sqrt, model5__min_samples_leaf=1, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=sqrt, model5__min_samples_leaf=2, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=sqrt, model5__min_samples_leaf=2, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=sqrt, model5__min_samples_leaf=2, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=sqrt, model5__min_samples_leaf=2, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=sqrt, model5__min_samples_leaf=2, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=sqrt, model5__min_samples_leaf=2, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=sqrt, model5__min_samples_leaf=2, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=sqrt, model5__min_samples_leaf=2, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=sqrt, model5__min_samples_leaf=2, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=sqrt, model5__min_samples_leaf=2, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=sqrt, model5__min_samples_leaf=2, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=sqrt, model5__min_samples_leaf=2, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=sqrt, model5__min_samples_leaf=2, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=sqrt, model5__min_samples_leaf=2, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=sqrt, model5__min_samples_leaf=2, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=sqrt, model5__min_samples_leaf=4, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=sqrt, model5__min_samples_leaf=4, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=sqrt, model5__min_samples_leaf=4, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=sqrt, model5__min_samples_leaf=4, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=sqrt, model5__min_samples_leaf=4, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=sqrt, model5__min_samples_leaf=4, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=sqrt, model5__min_samples_leaf=4, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=sqrt, model5__min_samples_leaf=4, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=sqrt, model5__min_samples_leaf=4, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=sqrt, model5__min_samples_leaf=4, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=sqrt, model5__min_samples_leaf=4, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=sqrt, model5__min_samples_leaf=4, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=sqrt, model5__min_samples_leaf=4, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=sqrt, model5__min_samples_leaf=4, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=sqrt, model5__min_samples_leaf=4, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=log2, model5__min_samples_leaf=1, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=log2, model5__min_samples_leaf=1, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=log2, model5__min_samples_leaf=1, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=log2, model5__min_samples_leaf=1, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=log2, model5__min_samples_leaf=1, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=log2, model5__min_samples_leaf=1, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=log2, model5__min_samples_leaf=1, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=log2, model5__min_samples_leaf=1, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=log2, model5__min_samples_leaf=1, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=log2, model5__min_samples_leaf=1, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=log2, model5__min_samples_leaf=1, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=log2, model5__min_samples_leaf=1, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=log2, model5__min_samples_leaf=1, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=log2, model5__min_samples_leaf=1, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=log2, model5__min_samples_leaf=1, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=log2, model5__min_samples_leaf=2, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=log2, model5__min_samples_leaf=2, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=log2, model5__min_samples_leaf=2, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=log2, model5__min_samples_leaf=2, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=log2, model5__min_samples_leaf=2, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=log2, model5__min_samples_leaf=2, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=log2, model5__min_samples_leaf=2, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=log2, model5__min_samples_leaf=2, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=log2, model5__min_samples_leaf=2, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=log2, model5__min_samples_leaf=2, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=log2, model5__min_samples_leaf=2, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=log2, model5__min_samples_leaf=2, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=log2, model5__min_samples_leaf=2, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=log2, model5__min_samples_leaf=2, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=log2, model5__min_samples_leaf=2, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=log2, model5__min_samples_leaf=4, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=log2, model5__min_samples_leaf=4, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=log2, model5__min_samples_leaf=4, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=log2, model5__min_samples_leaf=4, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=log2, model5__min_samples_leaf=4, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=log2, model5__min_samples_leaf=4, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=log2, model5__min_samples_leaf=4, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=log2, model5__min_samples_leaf=4, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=log2, model5__min_samples_leaf=4, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=log2, model5__min_samples_leaf=4, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=log2, model5__min_samples_leaf=4, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=log2, model5__min_samples_leaf=4, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=log2, model5__min_samples_leaf=4, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=log2, model5__min_samples_leaf=4, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=10, model5__max_features=log2, model5__min_samples_leaf=4, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=auto, model5__min_samples_leaf=1, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=auto, model5__min_samples_leaf=1, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=auto, model5__min_samples_leaf=1, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=auto, model5__min_samples_leaf=1, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=auto, model5__min_samples_leaf=1, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=auto, model5__min_samples_leaf=1, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=auto, model5__min_samples_leaf=1, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=auto, model5__min_samples_leaf=1, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=auto, model5__min_samples_leaf=1, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=auto, model5__min_samples_leaf=1, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=auto, model5__min_samples_leaf=1, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=auto, model5__min_samples_leaf=1, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=auto, model5__min_samples_leaf=1, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=auto, model5__min_samples_leaf=1, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=auto, model5__min_samples_leaf=1, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=auto, model5__min_samples_leaf=2, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=auto, model5__min_samples_leaf=2, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=auto, model5__min_samples_leaf=2, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=auto, model5__min_samples_leaf=2, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=auto, model5__min_samples_leaf=2, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=auto, model5__min_samples_leaf=2, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=auto, model5__min_samples_leaf=2, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=auto, model5__min_samples_leaf=2, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=auto, model5__min_samples_leaf=2, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=auto, model5__min_samples_leaf=2, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=auto, model5__min_samples_leaf=2, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=auto, model5__min_samples_leaf=2, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=auto, model5__min_samples_leaf=2, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=auto, model5__min_samples_leaf=2, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=auto, model5__min_samples_leaf=2, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=auto, model5__min_samples_leaf=4, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=auto, model5__min_samples_leaf=4, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=auto, model5__min_samples_leaf=4, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=auto, model5__min_samples_leaf=4, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=auto, model5__min_samples_leaf=4, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=auto, model5__min_samples_leaf=4, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=auto, model5__min_samples_leaf=4, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=auto, model5__min_samples_leaf=4, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=auto, model5__min_samples_leaf=4, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=auto, model5__min_samples_leaf=4, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=auto, model5__min_samples_leaf=4, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=auto, model5__min_samples_leaf=4, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=auto, model5__min_samples_leaf=4, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=auto, model5__min_samples_leaf=4, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=auto, model5__min_samples_leaf=4, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=sqrt, model5__min_samples_leaf=1, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=sqrt, model5__min_samples_leaf=1, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=sqrt, model5__min_samples_leaf=1, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=sqrt, model5__min_samples_leaf=1, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=sqrt, model5__min_samples_leaf=1, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=sqrt, model5__min_samples_leaf=1, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=sqrt, model5__min_samples_leaf=1, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=sqrt, model5__min_samples_leaf=1, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=sqrt, model5__min_samples_leaf=1, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=sqrt, model5__min_samples_leaf=1, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=sqrt, model5__min_samples_leaf=1, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=sqrt, model5__min_samples_leaf=1, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=sqrt, model5__min_samples_leaf=1, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=sqrt, model5__min_samples_leaf=1, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=sqrt, model5__min_samples_leaf=1, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=sqrt, model5__min_samples_leaf=2, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=sqrt, model5__min_samples_leaf=2, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=sqrt, model5__min_samples_leaf=2, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=sqrt, model5__min_samples_leaf=2, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=sqrt, model5__min_samples_leaf=2, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=sqrt, model5__min_samples_leaf=2, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=sqrt, model5__min_samples_leaf=2, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=sqrt, model5__min_samples_leaf=2, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=sqrt, model5__min_samples_leaf=2, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=sqrt, model5__min_samples_leaf=2, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=sqrt, model5__min_samples_leaf=2, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=sqrt, model5__min_samples_leaf=2, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=sqrt, model5__min_samples_leaf=2, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=sqrt, model5__min_samples_leaf=2, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=sqrt, model5__min_samples_leaf=2, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=sqrt, model5__min_samples_leaf=4, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=sqrt, model5__min_samples_leaf=4, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=sqrt, model5__min_samples_leaf=4, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=sqrt, model5__min_samples_leaf=4, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=sqrt, model5__min_samples_leaf=4, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=sqrt, model5__min_samples_leaf=4, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=sqrt, model5__min_samples_leaf=4, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=sqrt, model5__min_samples_leaf=4, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=20, model5__max_features=sqrt, model5__min_samples_leaf=4, model5__min_samples_split=5; total time=   0.0s
# ...
# [CV] END model5__max_depth=30, model5__max_features=auto, model5__min_samples_leaf=2, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=auto, model5__min_samples_leaf=2, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=auto, model5__min_samples_leaf=2, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=auto, model5__min_samples_leaf=2, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=auto, model5__min_samples_leaf=4, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=auto, model5__min_samples_leaf=4, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=auto, model5__min_samples_leaf=4, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=auto, model5__min_samples_leaf=4, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=auto, model5__min_samples_leaf=4, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=auto, model5__min_samples_leaf=4, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=auto, model5__min_samples_leaf=4, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=auto, model5__min_samples_leaf=4, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=auto, model5__min_samples_leaf=4, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=auto, model5__min_samples_leaf=4, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=auto, model5__min_samples_leaf=4, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=auto, model5__min_samples_leaf=4, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=auto, model5__min_samples_leaf=4, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=auto, model5__min_samples_leaf=4, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=auto, model5__min_samples_leaf=4, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=sqrt, model5__min_samples_leaf=1, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=sqrt, model5__min_samples_leaf=1, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=sqrt, model5__min_samples_leaf=1, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=sqrt, model5__min_samples_leaf=1, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=sqrt, model5__min_samples_leaf=1, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=sqrt, model5__min_samples_leaf=1, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=sqrt, model5__min_samples_leaf=1, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=sqrt, model5__min_samples_leaf=1, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=sqrt, model5__min_samples_leaf=1, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=sqrt, model5__min_samples_leaf=1, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=sqrt, model5__min_samples_leaf=1, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=sqrt, model5__min_samples_leaf=1, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=sqrt, model5__min_samples_leaf=1, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=sqrt, model5__min_samples_leaf=1, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=sqrt, model5__min_samples_leaf=1, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=sqrt, model5__min_samples_leaf=2, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=sqrt, model5__min_samples_leaf=2, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=sqrt, model5__min_samples_leaf=2, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=sqrt, model5__min_samples_leaf=2, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=sqrt, model5__min_samples_leaf=2, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=sqrt, model5__min_samples_leaf=2, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=sqrt, model5__min_samples_leaf=2, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=sqrt, model5__min_samples_leaf=2, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=sqrt, model5__min_samples_leaf=2, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=sqrt, model5__min_samples_leaf=2, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=sqrt, model5__min_samples_leaf=2, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=sqrt, model5__min_samples_leaf=2, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=sqrt, model5__min_samples_leaf=2, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=sqrt, model5__min_samples_leaf=2, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=sqrt, model5__min_samples_leaf=2, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=sqrt, model5__min_samples_leaf=4, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=sqrt, model5__min_samples_leaf=4, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=sqrt, model5__min_samples_leaf=4, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=sqrt, model5__min_samples_leaf=4, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=sqrt, model5__min_samples_leaf=4, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=sqrt, model5__min_samples_leaf=4, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=sqrt, model5__min_samples_leaf=4, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=sqrt, model5__min_samples_leaf=4, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=sqrt, model5__min_samples_leaf=4, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=sqrt, model5__min_samples_leaf=4, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=sqrt, model5__min_samples_leaf=4, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=sqrt, model5__min_samples_leaf=4, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=sqrt, model5__min_samples_leaf=4, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=sqrt, model5__min_samples_leaf=4, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=sqrt, model5__min_samples_leaf=4, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=log2, model5__min_samples_leaf=1, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=log2, model5__min_samples_leaf=1, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=log2, model5__min_samples_leaf=1, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=log2, model5__min_samples_leaf=1, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=log2, model5__min_samples_leaf=1, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=log2, model5__min_samples_leaf=1, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=log2, model5__min_samples_leaf=1, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=log2, model5__min_samples_leaf=1, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=log2, model5__min_samples_leaf=1, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=log2, model5__min_samples_leaf=1, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=log2, model5__min_samples_leaf=1, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=log2, model5__min_samples_leaf=1, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=log2, model5__min_samples_leaf=1, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=log2, model5__min_samples_leaf=1, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=log2, model5__min_samples_leaf=1, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=log2, model5__min_samples_leaf=2, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=log2, model5__min_samples_leaf=2, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=log2, model5__min_samples_leaf=2, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=log2, model5__min_samples_leaf=2, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=log2, model5__min_samples_leaf=2, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=log2, model5__min_samples_leaf=2, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=log2, model5__min_samples_leaf=2, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=log2, model5__min_samples_leaf=2, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=log2, model5__min_samples_leaf=2, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=log2, model5__min_samples_leaf=2, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=log2, model5__min_samples_leaf=2, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=log2, model5__min_samples_leaf=2, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=log2, model5__min_samples_leaf=2, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=log2, model5__min_samples_leaf=2, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=log2, model5__min_samples_leaf=2, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=log2, model5__min_samples_leaf=4, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=log2, model5__min_samples_leaf=4, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=log2, model5__min_samples_leaf=4, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=log2, model5__min_samples_leaf=4, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=log2, model5__min_samples_leaf=4, model5__min_samples_split=2; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=log2, model5__min_samples_leaf=4, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=log2, model5__min_samples_leaf=4, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=log2, model5__min_samples_leaf=4, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=log2, model5__min_samples_leaf=4, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=log2, model5__min_samples_leaf=4, model5__min_samples_split=5; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=log2, model5__min_samples_leaf=4, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=log2, model5__min_samples_leaf=4, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=log2, model5__min_samples_leaf=4, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=log2, model5__min_samples_leaf=4, model5__min_samples_split=10; total time=   0.0s
# [CV] END model5__max_depth=30, model5__max_features=log2, model5__min_samples_leaf=4, model5__min_samples_split=10; total time=   0.0s
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('col',
#                                         ColumnTransformer(transformers=[('standard',
#                                                                          StandardScaler(),
#                                                                          ['Age',
#                                                                           'Na_to_K']),
#                                                                         ('one',
#                                                                          OneHotEncoder(handle_unknown='ignore',
#                                                                                        sparse=False),
#                                                                          Index(['Age', 'Sex', 'BP', 'Cholesterol', 'Na_to_K'], dtype='object'))])),
#                                        ('model5', DecisionTreeClassifier())]),
#              param_grid={'model5__max_depth': [None, 10, 20, 30],
#                          'model5__max_features': ['auto', 'sqrt', 'log2'],
#                          'model5__min_samples_leaf': [1, 2, 4],
#                          'model5__min_samples_split': [2, 5, 10]},
#              scoring='f1', verbose=2)

# %%
newmodel
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('col',
#                                         ColumnTransformer(transformers=[('standard',
#                                                                          StandardScaler(),
#                                                                          ['Age',
#                                                                           'Na_to_K']),
#                                                                         ('one',
#                                                                          OneHotEncoder(handle_unknown='ignore',
#                                                                                        sparse=False),
#                                                                          Index(['Age', 'Sex', 'BP', 'Cholesterol', 'Na_to_K'], dtype='object'))])),
#                                        ('model5', DecisionTreeClassifier())]),
#              param_grid={'model5__max_depth': [None, 10, 20, 30],
#                          'model5__max_features': ['auto', 'sqrt', 'log2'],
#                          'model5__min_samples_leaf': [1, 2, 4],
#                          'model5__min_samples_split': [2, 5, 10]},
#              scoring='f1', verbose=2)

# %%
model8=newmodel.best_estimator_

# %%
model8.score(xtest,ytest)
# Out:
# 0.675

# %%
dttuned=cross_val_score(model8,data,target)

# %%
ypre=model8.predict(xtest)

# %% [markdown]
# <div style="background-color: #000; padding: 10px; text-align: center; border-radius: 5px; box-shadow: 0 0 10px rgba(255, 255, 255, 0.7);">
#     <p style="font-family: 'JetBrains Mono', monospace; font-weight: bold; letter-spacing: 2px; color: #3498db; font-size: 140%; text-shadow: 0 0 10px rgba(255, 255, 255, 0.7);">Logistic Regression Model Tuning</p>
# </div>

# %%
param_grid = {
    'model3__penalty': ['l2'],  # L1 or L2 regularization
    'model3__C': [0.001, 0.01, 0.1, 1, 10, 100],  # Regularization strength
    'model3__fit_intercept': [True, False],  # Whether to fit an intercept
    'model3__class_weight': [None, 'balanced'],  # Weights associated with classes
    'model3__solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga'],  # Optimization algorithm
    'model3__max_iter': [100, 200, 300],  # Maximum number of iterations
}

# %%
newmodel2=GridSearchCV(pipe3,param_grid,cv=5,scoring='f1',verbose=2)

# %%
newmodel2.fit(xtra,ytra)
# Out:
# Fitting 5 folds for each of 360 candidates, totalling 1800 fits
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=100, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=100, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=100, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=100, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=100, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=100, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=100, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=100, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=100, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=100, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=100, model3__penalty=l2, model3__solver=liblinear; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=100, model3__penalty=l2, model3__solver=liblinear; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=100, model3__penalty=l2, model3__solver=liblinear; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=100, model3__penalty=l2, model3__solver=liblinear; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=100, model3__penalty=l2, model3__solver=liblinear; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=100, model3__penalty=l2, model3__solver=sag; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=100, model3__penalty=l2, model3__solver=sag; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=100, model3__penalty=l2, model3__solver=sag; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=100, model3__penalty=l2, model3__solver=sag; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=100, model3__penalty=l2, model3__solver=sag; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=100, model3__penalty=l2, model3__solver=saga; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=100, model3__penalty=l2, model3__solver=saga; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=100, model3__penalty=l2, model3__solver=saga; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=100, model3__penalty=l2, model3__solver=saga; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=100, model3__penalty=l2, model3__solver=saga; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=200, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=200, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=200, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=200, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=200, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=200, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=200, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=200, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=200, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=200, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=200, model3__penalty=l2, model3__solver=liblinear; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=200, model3__penalty=l2, model3__solver=liblinear; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=200, model3__penalty=l2, model3__solver=liblinear; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=200, model3__penalty=l2, model3__solver=liblinear; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=200, model3__penalty=l2, model3__solver=liblinear; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=200, model3__penalty=l2, model3__solver=sag; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=200, model3__penalty=l2, model3__solver=sag; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=200, model3__penalty=l2, model3__solver=sag; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=200, model3__penalty=l2, model3__solver=sag; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=200, model3__penalty=l2, model3__solver=sag; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=200, model3__penalty=l2, model3__solver=saga; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=200, model3__penalty=l2, model3__solver=saga; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=200, model3__penalty=l2, model3__solver=saga; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=200, model3__penalty=l2, model3__solver=saga; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=200, model3__penalty=l2, model3__solver=saga; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=300, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=300, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=300, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=300, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=300, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=300, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=300, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=300, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=300, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=300, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=300, model3__penalty=l2, model3__solver=liblinear; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=300, model3__penalty=l2, model3__solver=liblinear; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=300, model3__penalty=l2, model3__solver=liblinear; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=300, model3__penalty=l2, model3__solver=liblinear; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=300, model3__penalty=l2, model3__solver=liblinear; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=300, model3__penalty=l2, model3__solver=sag; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=300, model3__penalty=l2, model3__solver=sag; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=300, model3__penalty=l2, model3__solver=sag; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=300, model3__penalty=l2, model3__solver=sag; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=300, model3__penalty=l2, model3__solver=sag; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=300, model3__penalty=l2, model3__solver=saga; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=300, model3__penalty=l2, model3__solver=saga; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=300, model3__penalty=l2, model3__solver=saga; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=300, model3__penalty=l2, model3__solver=saga; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=True, model3__max_iter=300, model3__penalty=l2, model3__solver=saga; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=liblinear; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=liblinear; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=liblinear; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=liblinear; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=liblinear; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=sag; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=sag; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=sag; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=sag; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=sag; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=saga; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=saga; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=saga; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=saga; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=saga; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=liblinear; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=liblinear; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=liblinear; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=liblinear; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=liblinear; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=sag; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=sag; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=sag; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=sag; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=sag; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=saga; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=saga; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=saga; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=saga; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=saga; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=300, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=300, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=300, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=300, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=300, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=300, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=300, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=300, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=300, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=300, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=300, model3__penalty=l2, model3__solver=liblinear; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=300, model3__penalty=l2, model3__solver=liblinear; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=300, model3__penalty=l2, model3__solver=liblinear; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=300, model3__penalty=l2, model3__solver=liblinear; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=300, model3__penalty=l2, model3__solver=liblinear; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=300, model3__penalty=l2, model3__solver=sag; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=300, model3__penalty=l2, model3__solver=sag; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=300, model3__penalty=l2, model3__solver=sag; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=300, model3__penalty=l2, model3__solver=sag; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=300, model3__penalty=l2, model3__solver=sag; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=300, model3__penalty=l2, model3__solver=saga; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=300, model3__penalty=l2, model3__solver=saga; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=300, model3__penalty=l2, model3__solver=saga; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=300, model3__penalty=l2, model3__solver=saga; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=None, model3__fit_intercept=False, model3__max_iter=300, model3__penalty=l2, model3__solver=saga; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=100, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=100, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=100, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=100, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=100, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=100, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=100, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=100, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=100, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=100, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=100, model3__penalty=l2, model3__solver=liblinear; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=100, model3__penalty=l2, model3__solver=liblinear; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=100, model3__penalty=l2, model3__solver=liblinear; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=100, model3__penalty=l2, model3__solver=liblinear; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=100, model3__penalty=l2, model3__solver=liblinear; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=100, model3__penalty=l2, model3__solver=sag; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=100, model3__penalty=l2, model3__solver=sag; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=100, model3__penalty=l2, model3__solver=sag; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=100, model3__penalty=l2, model3__solver=sag; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=100, model3__penalty=l2, model3__solver=sag; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=100, model3__penalty=l2, model3__solver=saga; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=100, model3__penalty=l2, model3__solver=saga; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=100, model3__penalty=l2, model3__solver=saga; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=100, model3__penalty=l2, model3__solver=saga; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=100, model3__penalty=l2, model3__solver=saga; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=200, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=200, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=200, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=200, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=200, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=200, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=200, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=200, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=200, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=200, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=200, model3__penalty=l2, model3__solver=liblinear; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=200, model3__penalty=l2, model3__solver=liblinear; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=200, model3__penalty=l2, model3__solver=liblinear; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=200, model3__penalty=l2, model3__solver=liblinear; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=200, model3__penalty=l2, model3__solver=liblinear; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=200, model3__penalty=l2, model3__solver=sag; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=200, model3__penalty=l2, model3__solver=sag; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=200, model3__penalty=l2, model3__solver=sag; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=200, model3__penalty=l2, model3__solver=sag; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=200, model3__penalty=l2, model3__solver=sag; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=200, model3__penalty=l2, model3__solver=saga; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=200, model3__penalty=l2, model3__solver=saga; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=200, model3__penalty=l2, model3__solver=saga; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=200, model3__penalty=l2, model3__solver=saga; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=200, model3__penalty=l2, model3__solver=saga; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=300, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=300, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=300, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=300, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=300, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=300, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=300, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=300, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=300, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=300, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=300, model3__penalty=l2, model3__solver=liblinear; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=300, model3__penalty=l2, model3__solver=liblinear; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=300, model3__penalty=l2, model3__solver=liblinear; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=300, model3__penalty=l2, model3__solver=liblinear; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=300, model3__penalty=l2, model3__solver=liblinear; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=300, model3__penalty=l2, model3__solver=sag; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=300, model3__penalty=l2, model3__solver=sag; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=300, model3__penalty=l2, model3__solver=sag; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=300, model3__penalty=l2, model3__solver=sag; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=300, model3__penalty=l2, model3__solver=sag; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=300, model3__penalty=l2, model3__solver=saga; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=300, model3__penalty=l2, model3__solver=saga; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=300, model3__penalty=l2, model3__solver=saga; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=300, model3__penalty=l2, model3__solver=saga; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=300, model3__penalty=l2, model3__solver=saga; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=liblinear; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=liblinear; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=liblinear; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=liblinear; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=liblinear; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=sag; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=sag; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=sag; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=sag; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=sag; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=saga; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=saga; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=saga; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=saga; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=saga; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=liblinear; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=liblinear; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=liblinear; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=liblinear; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=liblinear; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=sag; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=sag; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=sag; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=sag; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=sag; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=saga; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=saga; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=saga; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=saga; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=saga; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=300, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=300, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=300, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=300, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=300, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=300, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=300, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=300, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=300, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=300, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=0.001, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=300, model3__penalty=l2, model3__solver=liblinear; total time=   0.0s
# ...
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=300, model3__penalty=l2, model3__solver=liblinear; total time=   0.0s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=300, model3__penalty=l2, model3__solver=sag; total time=   0.3s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=300, model3__penalty=l2, model3__solver=sag; total time=   0.3s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=300, model3__penalty=l2, model3__solver=sag; total time=   0.3s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=300, model3__penalty=l2, model3__solver=sag; total time=   0.3s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=300, model3__penalty=l2, model3__solver=sag; total time=   0.3s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=300, model3__penalty=l2, model3__solver=saga; total time=   0.3s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=300, model3__penalty=l2, model3__solver=saga; total time=   0.3s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=300, model3__penalty=l2, model3__solver=saga; total time=   0.3s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=300, model3__penalty=l2, model3__solver=saga; total time=   0.3s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=True, model3__max_iter=300, model3__penalty=l2, model3__solver=saga; total time=   0.3s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=liblinear; total time=   0.0s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=liblinear; total time=   0.0s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=liblinear; total time=   0.0s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=liblinear; total time=   0.0s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=liblinear; total time=   0.0s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=sag; total time=   0.1s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=sag; total time=   0.1s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=sag; total time=   0.1s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=sag; total time=   0.1s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=sag; total time=   0.1s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=saga; total time=   0.1s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=saga; total time=   0.1s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=saga; total time=   0.1s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=saga; total time=   0.1s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=100, model3__penalty=l2, model3__solver=saga; total time=   0.1s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=liblinear; total time=   0.0s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=liblinear; total time=   0.0s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=liblinear; total time=   0.0s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=liblinear; total time=   0.0s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=liblinear; total time=   0.0s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=sag; total time=   0.2s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=sag; total time=   0.2s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=sag; total time=   0.2s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=sag; total time=   0.2s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=sag; total time=   0.2s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=saga; total time=   0.2s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=saga; total time=   0.2s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=saga; total time=   0.2s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=saga; total time=   0.2s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=200, model3__penalty=l2, model3__solver=saga; total time=   0.2s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=300, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=300, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=300, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=300, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=300, model3__penalty=l2, model3__solver=newton-cg; total time=   0.0s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=300, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=300, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=300, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=300, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=300, model3__penalty=l2, model3__solver=lbfgs; total time=   0.0s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=300, model3__penalty=l2, model3__solver=liblinear; total time=   0.0s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=300, model3__penalty=l2, model3__solver=liblinear; total time=   0.0s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=300, model3__penalty=l2, model3__solver=liblinear; total time=   0.0s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=300, model3__penalty=l2, model3__solver=liblinear; total time=   0.0s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=300, model3__penalty=l2, model3__solver=liblinear; total time=   0.0s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=300, model3__penalty=l2, model3__solver=sag; total time=   0.3s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=300, model3__penalty=l2, model3__solver=sag; total time=   0.3s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=300, model3__penalty=l2, model3__solver=sag; total time=   0.3s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=300, model3__penalty=l2, model3__solver=sag; total time=   0.3s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=300, model3__penalty=l2, model3__solver=sag; total time=   0.3s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=300, model3__penalty=l2, model3__solver=saga; total time=   0.3s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=300, model3__penalty=l2, model3__solver=saga; total time=   0.3s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=300, model3__penalty=l2, model3__solver=saga; total time=   0.3s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=300, model3__penalty=l2, model3__solver=saga; total time=   0.3s
# [CV] END model3__C=100, model3__class_weight=balanced, model3__fit_intercept=False, model3__max_iter=300, model3__penalty=l2, model3__solver=saga; total time=   0.3s
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('col',
#                                         ColumnTransformer(transformers=[('standard',
#                                                                          StandardScaler(),
#                                                                          ['Age',
#                                                                           'Na_to_K']),
#                                                                         ('one',
#                                                                          OneHotEncoder(handle_unknown='ignore',
#                                                                                        sparse=False),
#                                                                          Index(['Age', 'Sex', 'BP', 'Cholesterol', 'Na_to_K'], dtype='object'))])),
#                                        ('model3', LogisticRegression())]),
#              param_grid={'model3__C': [0.001, 0.01, 0.1, 1, 10, 100],
#                          'model3__class_weight': [None, 'balanced'],
#                          'model3__fit_intercept': [True, False],
#                          'model3__max_iter': [100, 200, 300],
#                          'model3__penalty': ['l2'],
#                          'model3__solver': ['newton-cg', 'lbfgs', 'liblinear',
#                                             'sag', 'saga']},
#              scoring='f1', verbose=2)

# %%
newmodel2
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('col',
#                                         ColumnTransformer(transformers=[('standard',
#                                                                          StandardScaler(),
#                                                                          ['Age',
#                                                                           'Na_to_K']),
#                                                                         ('one',
#                                                                          OneHotEncoder(handle_unknown='ignore',
#                                                                                        sparse=False),
#                                                                          Index(['Age', 'Sex', 'BP', 'Cholesterol', 'Na_to_K'], dtype='object'))])),
#                                        ('model3', LogisticRegression())]),
#              param_grid={'model3__C': [0.001, 0.01, 0.1, 1, 10, 100],
#                          'model3__class_weight': [None, 'balanced'],
#                          'model3__fit_intercept': [True, False],
#                          'model3__max_iter': [100, 200, 300],
#                          'model3__penalty': ['l2'],
#                          'model3__solver': ['newton-cg', 'lbfgs', 'liblinear',
#                                             'sag', 'saga']},
#              scoring='f1', verbose=2)

# %%
newmodel2_=newmodel2.best_estimator_

# %%
lrtuned=cross_val_score(newmodel2_,data,target)

# %% [markdown]
# <div style="background-color: #000; padding: 10px; text-align: center; border-radius: 5px; box-shadow: 0 0 10px rgba(255, 255, 255, 0.7);">
#     <p style="font-family: 'JetBrains Mono', monospace; font-weight: bold; letter-spacing: 2px; color: #3498db; font-size: 140%; text-shadow: 0 0 10px rgba(255, 255, 255, 0.7);">Random Forest Model Tuning</p>
# </div>

# %%
param_grid = {
    'model1__n_estimators': [50, 100, 200],  # Number of trees in the forest
    'model1__max_depth': [None, 10, 20, 30],  # Maximum depth of the tree
    'model1__min_samples_split': [2, 5, 10],  # The minimum number of samples required to split an internal node
    'model1__min_samples_leaf': [1, 2, 4],  # The minimum number of samples required to be at a leaf node
    'model1__max_features': ['auto', 'sqrt', 'log2'],  # The number of features to consider when looking for the best split
}

# %%
newmodel3=GridSearchCV(pipe1,param_grid,cv=5,scoring='f1',verbose=2)

# %%
newmodel3.fit(xtra,ytra)
# Out:
# Fitting 5 folds for each of 324 candidates, totalling 1620 fits
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=1, model1__min_samples_split=2, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=1, model1__min_samples_split=2, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=1, model1__min_samples_split=2, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=1, model1__min_samples_split=2, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=1, model1__min_samples_split=2, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=1, model1__min_samples_split=2, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=1, model1__min_samples_split=2, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=1, model1__min_samples_split=2, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=1, model1__min_samples_split=2, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=1, model1__min_samples_split=2, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=1, model1__min_samples_split=2, model1__n_estimators=200; total time=   0.4s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=1, model1__min_samples_split=2, model1__n_estimators=200; total time=   0.4s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=1, model1__min_samples_split=2, model1__n_estimators=200; total time=   0.4s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=1, model1__min_samples_split=2, model1__n_estimators=200; total time=   0.4s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=1, model1__min_samples_split=2, model1__n_estimators=200; total time=   0.4s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=1, model1__min_samples_split=5, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=1, model1__min_samples_split=5, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=1, model1__min_samples_split=5, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=1, model1__min_samples_split=5, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=1, model1__min_samples_split=5, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=1, model1__min_samples_split=5, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=1, model1__min_samples_split=5, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=1, model1__min_samples_split=5, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=1, model1__min_samples_split=5, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=1, model1__min_samples_split=5, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=1, model1__min_samples_split=5, model1__n_estimators=200; total time=   0.4s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=1, model1__min_samples_split=5, model1__n_estimators=200; total time=   0.4s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=1, model1__min_samples_split=5, model1__n_estimators=200; total time=   0.4s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=1, model1__min_samples_split=5, model1__n_estimators=200; total time=   0.4s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=1, model1__min_samples_split=5, model1__n_estimators=200; total time=   0.4s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=1, model1__min_samples_split=10, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=1, model1__min_samples_split=10, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=1, model1__min_samples_split=10, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=1, model1__min_samples_split=10, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=1, model1__min_samples_split=10, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=1, model1__min_samples_split=10, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=1, model1__min_samples_split=10, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=1, model1__min_samples_split=10, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=1, model1__min_samples_split=10, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=1, model1__min_samples_split=10, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=1, model1__min_samples_split=10, model1__n_estimators=200; total time=   0.4s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=1, model1__min_samples_split=10, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=1, model1__min_samples_split=10, model1__n_estimators=200; total time=   0.4s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=1, model1__min_samples_split=10, model1__n_estimators=200; total time=   0.4s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=1, model1__min_samples_split=10, model1__n_estimators=200; total time=   0.4s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=2, model1__min_samples_split=2, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=2, model1__min_samples_split=2, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=2, model1__min_samples_split=2, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=2, model1__min_samples_split=2, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=2, model1__min_samples_split=2, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=2, model1__min_samples_split=2, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=2, model1__min_samples_split=2, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=2, model1__min_samples_split=2, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=2, model1__min_samples_split=2, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=2, model1__min_samples_split=2, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=2, model1__min_samples_split=2, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=2, model1__min_samples_split=2, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=2, model1__min_samples_split=2, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=2, model1__min_samples_split=2, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=2, model1__min_samples_split=2, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=2, model1__min_samples_split=5, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=2, model1__min_samples_split=5, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=2, model1__min_samples_split=5, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=2, model1__min_samples_split=5, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=2, model1__min_samples_split=5, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=2, model1__min_samples_split=5, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=2, model1__min_samples_split=5, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=2, model1__min_samples_split=5, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=2, model1__min_samples_split=5, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=2, model1__min_samples_split=5, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=2, model1__min_samples_split=5, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=2, model1__min_samples_split=5, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=2, model1__min_samples_split=5, model1__n_estimators=200; total time=   0.4s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=2, model1__min_samples_split=5, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=2, model1__min_samples_split=5, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=2, model1__min_samples_split=10, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=2, model1__min_samples_split=10, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=2, model1__min_samples_split=10, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=2, model1__min_samples_split=10, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=2, model1__min_samples_split=10, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=2, model1__min_samples_split=10, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=2, model1__min_samples_split=10, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=2, model1__min_samples_split=10, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=2, model1__min_samples_split=10, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=2, model1__min_samples_split=10, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=2, model1__min_samples_split=10, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=2, model1__min_samples_split=10, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=2, model1__min_samples_split=10, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=2, model1__min_samples_split=10, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=2, model1__min_samples_split=10, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=4, model1__min_samples_split=2, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=4, model1__min_samples_split=2, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=4, model1__min_samples_split=2, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=4, model1__min_samples_split=2, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=4, model1__min_samples_split=2, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=4, model1__min_samples_split=2, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=4, model1__min_samples_split=2, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=4, model1__min_samples_split=2, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=4, model1__min_samples_split=2, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=4, model1__min_samples_split=2, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=4, model1__min_samples_split=2, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=4, model1__min_samples_split=2, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=4, model1__min_samples_split=2, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=4, model1__min_samples_split=2, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=4, model1__min_samples_split=2, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=4, model1__min_samples_split=5, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=4, model1__min_samples_split=5, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=4, model1__min_samples_split=5, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=4, model1__min_samples_split=5, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=4, model1__min_samples_split=5, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=4, model1__min_samples_split=5, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=4, model1__min_samples_split=5, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=4, model1__min_samples_split=5, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=4, model1__min_samples_split=5, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=4, model1__min_samples_split=5, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=4, model1__min_samples_split=5, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=4, model1__min_samples_split=5, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=4, model1__min_samples_split=5, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=4, model1__min_samples_split=5, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=4, model1__min_samples_split=5, model1__n_estimators=200; total time=   0.4s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=4, model1__min_samples_split=10, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=4, model1__min_samples_split=10, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=4, model1__min_samples_split=10, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=4, model1__min_samples_split=10, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=4, model1__min_samples_split=10, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=4, model1__min_samples_split=10, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=4, model1__min_samples_split=10, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=4, model1__min_samples_split=10, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=4, model1__min_samples_split=10, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=4, model1__min_samples_split=10, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=4, model1__min_samples_split=10, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=4, model1__min_samples_split=10, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=4, model1__min_samples_split=10, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=4, model1__min_samples_split=10, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=None, model1__max_features=auto, model1__min_samples_leaf=4, model1__min_samples_split=10, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=1, model1__min_samples_split=2, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=1, model1__min_samples_split=2, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=1, model1__min_samples_split=2, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=1, model1__min_samples_split=2, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=1, model1__min_samples_split=2, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=1, model1__min_samples_split=2, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=1, model1__min_samples_split=2, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=1, model1__min_samples_split=2, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=1, model1__min_samples_split=2, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=1, model1__min_samples_split=2, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=1, model1__min_samples_split=2, model1__n_estimators=200; total time=   0.4s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=1, model1__min_samples_split=2, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=1, model1__min_samples_split=2, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=1, model1__min_samples_split=2, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=1, model1__min_samples_split=2, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=1, model1__min_samples_split=5, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=1, model1__min_samples_split=5, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=1, model1__min_samples_split=5, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=1, model1__min_samples_split=5, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=1, model1__min_samples_split=5, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=1, model1__min_samples_split=5, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=1, model1__min_samples_split=5, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=1, model1__min_samples_split=5, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=1, model1__min_samples_split=5, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=1, model1__min_samples_split=5, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=1, model1__min_samples_split=5, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=1, model1__min_samples_split=5, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=1, model1__min_samples_split=5, model1__n_estimators=200; total time=   0.4s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=1, model1__min_samples_split=5, model1__n_estimators=200; total time=   0.4s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=1, model1__min_samples_split=5, model1__n_estimators=200; total time=   0.4s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=1, model1__min_samples_split=10, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=1, model1__min_samples_split=10, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=1, model1__min_samples_split=10, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=1, model1__min_samples_split=10, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=1, model1__min_samples_split=10, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=1, model1__min_samples_split=10, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=1, model1__min_samples_split=10, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=1, model1__min_samples_split=10, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=1, model1__min_samples_split=10, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=1, model1__min_samples_split=10, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=1, model1__min_samples_split=10, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=1, model1__min_samples_split=10, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=1, model1__min_samples_split=10, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=1, model1__min_samples_split=10, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=1, model1__min_samples_split=10, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=2, model1__min_samples_split=2, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=2, model1__min_samples_split=2, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=2, model1__min_samples_split=2, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=2, model1__min_samples_split=2, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=2, model1__min_samples_split=2, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=2, model1__min_samples_split=2, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=2, model1__min_samples_split=2, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=2, model1__min_samples_split=2, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=2, model1__min_samples_split=2, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=2, model1__min_samples_split=2, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=2, model1__min_samples_split=2, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=2, model1__min_samples_split=2, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=2, model1__min_samples_split=2, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=2, model1__min_samples_split=2, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=2, model1__min_samples_split=2, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=2, model1__min_samples_split=5, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=2, model1__min_samples_split=5, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=2, model1__min_samples_split=5, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=2, model1__min_samples_split=5, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=2, model1__min_samples_split=5, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=2, model1__min_samples_split=5, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=2, model1__min_samples_split=5, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=2, model1__min_samples_split=5, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=2, model1__min_samples_split=5, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=2, model1__min_samples_split=5, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=2, model1__min_samples_split=5, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=2, model1__min_samples_split=5, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=2, model1__min_samples_split=5, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=2, model1__min_samples_split=5, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=2, model1__min_samples_split=5, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=2, model1__min_samples_split=10, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=2, model1__min_samples_split=10, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=2, model1__min_samples_split=10, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=2, model1__min_samples_split=10, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=2, model1__min_samples_split=10, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=2, model1__min_samples_split=10, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=2, model1__min_samples_split=10, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=2, model1__min_samples_split=10, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=2, model1__min_samples_split=10, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=2, model1__min_samples_split=10, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=2, model1__min_samples_split=10, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=2, model1__min_samples_split=10, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=2, model1__min_samples_split=10, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=2, model1__min_samples_split=10, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=2, model1__min_samples_split=10, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=4, model1__min_samples_split=2, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=4, model1__min_samples_split=2, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=4, model1__min_samples_split=2, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=4, model1__min_samples_split=2, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=4, model1__min_samples_split=2, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=4, model1__min_samples_split=2, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=4, model1__min_samples_split=2, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=4, model1__min_samples_split=2, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=4, model1__min_samples_split=2, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=4, model1__min_samples_split=2, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=4, model1__min_samples_split=2, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=4, model1__min_samples_split=2, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=4, model1__min_samples_split=2, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=4, model1__min_samples_split=2, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=4, model1__min_samples_split=2, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=4, model1__min_samples_split=5, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=4, model1__min_samples_split=5, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=4, model1__min_samples_split=5, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=4, model1__min_samples_split=5, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=4, model1__min_samples_split=5, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=4, model1__min_samples_split=5, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=4, model1__min_samples_split=5, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=4, model1__min_samples_split=5, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=4, model1__min_samples_split=5, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=4, model1__min_samples_split=5, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=4, model1__min_samples_split=5, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=4, model1__min_samples_split=5, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=4, model1__min_samples_split=5, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=4, model1__min_samples_split=5, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=4, model1__min_samples_split=5, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=4, model1__min_samples_split=10, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=4, model1__min_samples_split=10, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=4, model1__min_samples_split=10, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=4, model1__min_samples_split=10, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=4, model1__min_samples_split=10, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=4, model1__min_samples_split=10, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=4, model1__min_samples_split=10, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=4, model1__min_samples_split=10, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=4, model1__min_samples_split=10, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=4, model1__min_samples_split=10, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=4, model1__min_samples_split=10, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=4, model1__min_samples_split=10, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=4, model1__min_samples_split=10, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=4, model1__min_samples_split=10, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=None, model1__max_features=sqrt, model1__min_samples_leaf=4, model1__min_samples_split=10, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=None, model1__max_features=log2, model1__min_samples_leaf=1, model1__min_samples_split=2, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=log2, model1__min_samples_leaf=1, model1__min_samples_split=2, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=log2, model1__min_samples_leaf=1, model1__min_samples_split=2, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=log2, model1__min_samples_leaf=1, model1__min_samples_split=2, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=log2, model1__min_samples_leaf=1, model1__min_samples_split=2, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=log2, model1__min_samples_leaf=1, model1__min_samples_split=2, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=log2, model1__min_samples_leaf=1, model1__min_samples_split=2, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=log2, model1__min_samples_leaf=1, model1__min_samples_split=2, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=log2, model1__min_samples_leaf=1, model1__min_samples_split=2, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=log2, model1__min_samples_leaf=1, model1__min_samples_split=2, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=log2, model1__min_samples_leaf=1, model1__min_samples_split=2, model1__n_estimators=200; total time=   0.4s
# [CV] END model1__max_depth=None, model1__max_features=log2, model1__min_samples_leaf=1, model1__min_samples_split=2, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=None, model1__max_features=log2, model1__min_samples_leaf=1, model1__min_samples_split=2, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=None, model1__max_features=log2, model1__min_samples_leaf=1, model1__min_samples_split=2, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=None, model1__max_features=log2, model1__min_samples_leaf=1, model1__min_samples_split=2, model1__n_estimators=200; total time=   0.4s
# [CV] END model1__max_depth=None, model1__max_features=log2, model1__min_samples_leaf=1, model1__min_samples_split=5, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=log2, model1__min_samples_leaf=1, model1__min_samples_split=5, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=log2, model1__min_samples_leaf=1, model1__min_samples_split=5, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=log2, model1__min_samples_leaf=1, model1__min_samples_split=5, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=log2, model1__min_samples_leaf=1, model1__min_samples_split=5, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=None, model1__max_features=log2, model1__min_samples_leaf=1, model1__min_samples_split=5, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=log2, model1__min_samples_leaf=1, model1__min_samples_split=5, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=log2, model1__min_samples_leaf=1, model1__min_samples_split=5, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=log2, model1__min_samples_leaf=1, model1__min_samples_split=5, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=None, model1__max_features=log2, model1__min_samples_leaf=1, model1__min_samples_split=5, model1__n_estimators=100; total time=   0.2s
# ...
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=1, model1__min_samples_split=10, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=2, model1__min_samples_split=2, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=2, model1__min_samples_split=2, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=2, model1__min_samples_split=2, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=2, model1__min_samples_split=2, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=2, model1__min_samples_split=2, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=2, model1__min_samples_split=2, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=2, model1__min_samples_split=2, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=2, model1__min_samples_split=2, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=2, model1__min_samples_split=2, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=2, model1__min_samples_split=2, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=2, model1__min_samples_split=2, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=2, model1__min_samples_split=2, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=2, model1__min_samples_split=2, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=2, model1__min_samples_split=2, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=2, model1__min_samples_split=2, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=2, model1__min_samples_split=5, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=2, model1__min_samples_split=5, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=2, model1__min_samples_split=5, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=2, model1__min_samples_split=5, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=2, model1__min_samples_split=5, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=2, model1__min_samples_split=5, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=2, model1__min_samples_split=5, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=2, model1__min_samples_split=5, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=2, model1__min_samples_split=5, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=2, model1__min_samples_split=5, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=2, model1__min_samples_split=5, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=2, model1__min_samples_split=5, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=2, model1__min_samples_split=5, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=2, model1__min_samples_split=5, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=2, model1__min_samples_split=5, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=2, model1__min_samples_split=10, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=2, model1__min_samples_split=10, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=2, model1__min_samples_split=10, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=2, model1__min_samples_split=10, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=2, model1__min_samples_split=10, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=2, model1__min_samples_split=10, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=2, model1__min_samples_split=10, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=2, model1__min_samples_split=10, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=2, model1__min_samples_split=10, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=2, model1__min_samples_split=10, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=2, model1__min_samples_split=10, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=2, model1__min_samples_split=10, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=2, model1__min_samples_split=10, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=2, model1__min_samples_split=10, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=2, model1__min_samples_split=10, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=4, model1__min_samples_split=2, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=4, model1__min_samples_split=2, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=4, model1__min_samples_split=2, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=4, model1__min_samples_split=2, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=4, model1__min_samples_split=2, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=4, model1__min_samples_split=2, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=4, model1__min_samples_split=2, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=4, model1__min_samples_split=2, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=4, model1__min_samples_split=2, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=4, model1__min_samples_split=2, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=4, model1__min_samples_split=2, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=4, model1__min_samples_split=2, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=4, model1__min_samples_split=2, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=4, model1__min_samples_split=2, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=4, model1__min_samples_split=2, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=4, model1__min_samples_split=5, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=4, model1__min_samples_split=5, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=4, model1__min_samples_split=5, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=4, model1__min_samples_split=5, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=4, model1__min_samples_split=5, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=4, model1__min_samples_split=5, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=4, model1__min_samples_split=5, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=4, model1__min_samples_split=5, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=4, model1__min_samples_split=5, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=4, model1__min_samples_split=5, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=4, model1__min_samples_split=5, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=4, model1__min_samples_split=5, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=4, model1__min_samples_split=5, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=4, model1__min_samples_split=5, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=4, model1__min_samples_split=5, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=4, model1__min_samples_split=10, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=4, model1__min_samples_split=10, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=4, model1__min_samples_split=10, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=4, model1__min_samples_split=10, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=4, model1__min_samples_split=10, model1__n_estimators=50; total time=   0.1s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=4, model1__min_samples_split=10, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=4, model1__min_samples_split=10, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=4, model1__min_samples_split=10, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=4, model1__min_samples_split=10, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=4, model1__min_samples_split=10, model1__n_estimators=100; total time=   0.2s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=4, model1__min_samples_split=10, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=4, model1__min_samples_split=10, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=4, model1__min_samples_split=10, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=4, model1__min_samples_split=10, model1__n_estimators=200; total time=   0.3s
# [CV] END model1__max_depth=30, model1__max_features=log2, model1__min_samples_leaf=4, model1__min_samples_split=10, model1__n_estimators=200; total time=   0.3s
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('col',
#                                         ColumnTransformer(transformers=[('standard',
#                                                                          StandardScaler(),
#                                                                          ['Age',
#                                                                           'Na_to_K']),
#                                                                         ('one',
#                                                                          OneHotEncoder(handle_unknown='ignore',
#                                                                                        sparse=False),
#                                                                          Index(['Age', 'Sex', 'BP', 'Cholesterol', 'Na_to_K'], dtype='object'))])),
#                                        ('model1', RandomForestClassifier())]),
#              param_grid={'model1__max_depth': [None, 10, 20, 30],
#                          'model1__max_features': ['auto', 'sqrt', 'log2'],
#                          'model1__min_samples_leaf': [1, 2, 4],
#                          'model1__min_samples_split': [2, 5, 10],
#                          'model1__n_estimators': [50, 100, 200]},
#              scoring='f1', verbose=2)

# %%
newmodel3_=newmodel3.best_estimator_

# %%
newmodel3_.score(xtest,ytest)
# Out:
# 0.925

# %%
rftuned=cross_val_score(newmodel3_,data,target)

# %%
tunedmodels=['RandomForestClassifier','LogisticRegression','DecisionTreeClassifier']
tunedmodelscrossval=[rftuned,lrtuned,dttuned]

# %% [markdown]
# # <p style="font-family:JetBrains Mono; font-weight:bold; letter-spacing: 2px; color:#4F200D; font-size:140%; text-align:center;padding: 0px; border-bottom: 3px solid #4F200D">Final Results</p>

# %%
mean=[]
for i in modelcrossval:
    mean.append(i.mean())
tunedmean=[]
for i in tunedmodelscrossval:
    tunedmean.append(i.mean())

# %%
pd.DataFrame(dict(Models=models,Cross_Val_scores=modelcrossval,means=mean,Tuned_Models=tunedmodels+['-']*4,Tuned_Models_Cross_Val_Scores=tunedmodelscrossval+['-']*4,Tuned_Model_Means=tunedmean+['-']*4))
# Out:
#                    Models                   Cross_Val_scores  means  \
# 0  RandomForestClassifier        [0.975, 1.0, 1.0, 0.9, 1.0]  0.975
# 1      LogisticRegression  [0.625, 0.875, 0.75, 0.875, 0.75]  0.775
# 2  DecisionTreeClassifier    [0.875, 0.875, 0.875, 1.0, 1.0]  0.925
# 3              RidgeModel     [0.5, 0.75, 0.625, 0.75, 0.75]  0.675
# 4              LassoModel     [0.5, 0.75, 0.625, 0.75, 0.75]  0.675
# 5                     SVC    [0.625, 0.625, 0.5, 0.75, 0.75]  0.650
# 6    KNeighborsClassifier   [0.375, 0.75, 0.625, 0.875, 1.0]  0.725
#
#              Tuned_Models     Tuned_Models_Cross_Val_Scores Tuned_Model_Means
# 0  RandomForestClassifier         [1.0, 1.0, 1.0, 0.9, 1.0]              0.98
# 1      LogisticRegression   [0.475, 0.45, 0.45, 0.45, 0.45]             0.455
# 2  DecisionTreeClassifier  [0.625, 0.925, 0.85, 0.675, 0.9]             0.795
# 3                       -                                 -                 -
# 4                       -                                 -                 -
# 5                       -                                 -                 -
# 6                       -                                 -                 -

# %% [markdown]
# <div style="border-radius: 10px; border: rgb(41, 128, 185) solid; padding: 15px; background-color: rgb(52, 73, 94); font-size: 100%; text-align: left; color: #ecf0f1; box-shadow: 0 0 15px rgba(41, 128, 185, 0.7);">
#     <ul style="margin: 0; padding-left: 20px; list-style-type: square;">
#         <li><strong>Decision Tree Classifier is a Robust Model as well as a Good Model</strong></li>
#     </ul>
# </div>

# %% [markdown]
# <div style="background-color: #000; padding: 10px; text-align: center; border-radius: 5px; box-shadow: 0 0 10px rgba(255, 255, 255, 0.7);">
#     <p style="font-family: 'JetBrains Mono', monospace; font-weight: bold; letter-spacing: 2px; color: #3498db; font-size: 140%; text-shadow: 0 0 10px rgba(255, 255, 255, 0.7);">Model Saving</p>
# </div>

# %%
pk.dump(model5,open('/kaggle/working/model.pkl','wb'))

# %% [markdown]
# <div style="background-color: #000; padding: 10px; text-align: center; border-radius: 5px; box-shadow: 0 0 10px rgba(255, 255, 255, 0.7);">
#     <p style="font-family: 'JetBrains Mono', monospace; font-weight: bold; letter-spacing: 2px; color: #3498db; font-size: 140%; text-shadow: 0 0 10px rgba(255, 255, 255, 0.7);">Model Loading</p>
# </div>

# %%
model=pk.load(open('/kaggle/working/model.pkl','rb'))
data=pd.read_csv('/kaggle/input/drug-classification/drug200.csv')

# %% [markdown]
# # <p style="font-family:JetBrains Mono; font-weight:bold; letter-spacing: 2px; color:#4F200D; font-size:140%; text-align:center;padding: 0px; border-bottom: 3px solid #4F200D">Model Utilization</p>

# %%
"""rows=[]
n=int(input('Enter the no of records : '))
print("Sample Inputs Age(int-range(15-74)),Sex(F or M),BP(HIGH or LOW or NORMAL),Cholesterol(HIGH OR NORMAL),Na_to_k(float-range(6-39))")
for i in range(n):
  print('FOR {} Record :'.format(i+1))
  row=[]
  for j in range(len(data.columns)-1):
    if j==0:
      k=int(input('Enter the value (%s):'%(data.columns[j])))
    else:
      k=input('Enter the value (%s):'%(data.columns[j]))
    row.append(k)
  rows.append(row)
newtable=pd.DataFrame(rows,columns=data.columns[:-1])
ans=model.predict(newtable)
def answer(ansarr):
  ans1=[]
  for i in ans:
    if i==0:
      ans1.append('DrugY')
    elif i==1:
      ans1.append('DrugA')
    elif i==2:
      ans1.append('DrugB')
    elif i==3:
      ans1.append('DrugC')
    elif i==4:
      ans1.append('DrugX')
  return ans1

for i in range(len(ans)):
  print(f"'Record'{(i+1): }: "+answer(ans)[i])"""
# Out:
# 'rows=[]\nn=int(input(\'Enter the no of records : \'))\nprint("Sample Inputs Age(int-range(15-74)),Sex(F or M),BP(HIGH or LOW or NORMAL),Cholesterol(HIGH OR NORMAL),Na_to_k(float-range(6-39))")\nfor i in range(n):\n  print(\'FOR {} Record :\'.format(i+1))\n  row=[]\n  for j in range(len(data.columns)-1):\n    if j==0:\n      k=int(input(\'Enter the value (%s):\'%(data.columns[j])))\n    else:\n      k=input(\'Enter the value (%s):\'%(data.columns[j]))\n    row.append(k)\n  rows.append(row)\nnewtable=pd.DataFrame(rows,columns=data.columns[:-1])\nans=model.predict(newtable)\ndef answer(ansarr):\n  ans1=[]\n  for i in ans:\n    if i==0:\n      ans1.append(\'DrugY\')\n    elif i==1:\n      ans1.append(\'DrugA\')\n    elif i==2:\n      ans1.append(\'DrugB\')\n    elif i==3:\n      ans1.append(\'DrugC\')\n    elif i==4:\n      ans1.append(\'DrugX\')\n  return ans1\n\nfor i in range(len(ans)):\n  print(f"\'Record\'{(i+1): }: "+answer(ans)[i])'

# %% [markdown]
# <div style="border-radius: 10px; border: 2px solid #3498db; padding: 15px; background-color: #000; font-size: 120%; text-align: center; color: #3498db; box-shadow: 0 0 15px rgba(52, 152, 219, 0.7);">
#     <p style="margin: 0; font-weight: bold; font-size: 150%; color: #3498db;">Thank You!</p>
#     <p style="margin: 10px 0 20px; color: #3498db;">Wishing you a day filled with tranquility and positivity!</p>
#     <p style="margin: 0; color: #3498db;">Explore the calm and soothing content we have in store for you.</p>
# </div>
